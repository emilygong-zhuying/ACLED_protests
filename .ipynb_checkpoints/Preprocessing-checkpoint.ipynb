# %%
import pandas as pd
import numpy as np

# %%
protests = pd.read_csv('1900-01-01-2022-11-18protests.csv')
protests_copy = pd.read_csv('1900-01-01-2022-11-18protests.csv')

# %% [markdown]
# # Convert event_time from string to datetime object

# %%
from datetime import datetime
def convert_to_datetime(date_string):
    return datetime.strptime(date_string, "%d %B %Y").date()

# %%
protests["event_date"] = protests["event_date"].apply(convert_to_datetime)

# %%
protests.to_csv("protests_clean.csv", index = False)

# %%
# for debugging 
# head = protests.head()
# interested = protests[['data_id', 'event_id_no_cnty', 'event_date', 'year', 'event_type', 'sub_event_type']]
# notes = protests[['notes']]
# note = notes.iat[6841,0]
# note

# %% [markdown]
# # Extract Protest Size from Notes Col

# %%
def extract_size(s):
    if type(s) == str:
        pos = s.rfind("[size")
        pos2 = s.rfind("[Size")
        pos3 = s.rfind("(size")
        pos4 = s.rfind("[Szie")
        pos5 = s.rfind("Size")
        if pos == -1 and pos2 == -1 and pos3 == -1 and pos4 == -1 and pos5 == -1:
            s = None
        else:
            s = s[pos+1:]
            pos2 = s.find("]")
            s = s[:pos2]
            if s[-1] == ".":
                s = s[:-1]
                s = s[s.find("=")+1:]
            else:
                s = s[s.find("=")+1:]
        if type(s) == str and len(s) > 1:
            if s[0] == " ":
                s = s[1:]
            if s[0] == "'":
                s = s[1:-1]
    else:
        s = None
    return s

# %%
# first, take out None values in the notes column
protests = protests[~protests['notes'].isnull()]

# added a column of size with information extracted from notes column
protests['size'] = protests['notes'].apply(extract_size)

# %%
len(protests)/len(protests_copy)
# Out:
# 0.9993719407914136

# %%
size_not_reported = protests[protests['size'].isnull()].reset_index(drop=True)
# text = size_reported.at[0, 'notes']
for i in range(100,110):
    print(size_not_reported.at[i, 'notes'], "\n")
# len(size_not_reported)/len(protests_copy)
# Out:
# On 9 March 2019, protesters closed the vehicular traffic on the Pan-American Highway in San Antonio de los Altos, Miranda state. The reason for the riot is the electric shutdown that left the country for more than 50 hours without light.
#
# On 9 March 2019, inhabitants of Barquisimeto, Lara state, concentrated in the streets in response to the call made by Juan Guaido, interim president of Venezuela. People gathered with Venezuelan flags and banners, while they chanted slogans.
#
# On 9 March 2019, protesters in La Florida, Distrito Capital Caracas, made their pots sound to show their discontent with the more than 48 hours that the country has no electricity.
#
# On 9 March 2019, demonstrators blocked the passage of vehicles on the Pan-American highway in Los Teques, Miranda state. The citizens complied with the call of interim president Juan Guaido to take to the streets to demonstrate against Nicolas Maduro.
#
# On 9 March 2019, people in Barcelona, Anzoategui state, concentrated to express their rejection of the electric blackouts that occurred throughout the national territory since March 7 and in response to the call made by Juan Guaido, interim president of Venezuela.
#
# On 9 March 2019, protesters in Chuao in Caracas went out to the streets after more than 50 hours without electric service. Rioters kept the public street locked.
#
# On 9 March 2019, protesters in the municipality of Sucre made their pots sound to show their discontent with the more than 48 hours that the country has no electricity.
#
# On 9 March 2019, protesters in Chacao municipality made their pots sound to show their discontent with the more than 48 hours that the country has no electricity.
#
# On 9 March 2019, demonstrators concentrated on the Francisco Fajardo highway, near Las Mercedes, in Miranda state, after a national electric shutdown that has left the country for more than 60 hours without electricity.
#
# On 9 March 2019, police forces blocked the rally called for the opposition on Victoria Avenue in Caracas. PNB officials sprayed tear gas.

# %%
size_reported = protests[~protests['size'].isnull()] 

# There may be other values I'm missing
size_reported = size_reported[size_reported['size'] != "no report"]
size_reported = size_reported[size_reported['size'] != "No Report"]
size_reported = size_reported[size_reported['size'] != "no eport"]
size_reported = size_reported[size_reported['size'] != "no reports"]
size_reported = size_reported[size_reported['size'] != "no reply"]
size_reported = size_reported[size_reported['size'] != "no review"]

count_size = len(size_reported)
count_unique = len(size_reported['event_id_cnty'].unique())
print(count_size/len(protests), 'of the dataset have actual information on size')
print(count_unique/len(protests), 'of the dataset are unique events with actual information on size')
# Out:
# 0.25218409864071023 of the dataset have actual information on size
# 0.25218409864071023 of the dataset are unique events with actual information on size

# %%
print("There are", len(size_reported['event_id_no_cnty'].unique()), "unique events with some information of protest size")
# Out:
# There are 54969 unique events with some information of protest size

# %%
print("There are", len(size_reported['size'].unique()), "unique values in size")
# Out:
# There are 7992 unique values in size

# %%
def convert_to_numerical(size_string):
    try:
        size_string = int(size_string)
    except:
        size_string = None
    return size_string

# %%
size_reported['numerical_size'] = size_reported['size'].apply(convert_to_numerical)

# %%
print(len(size_reported[~size_reported['numerical_size'].isnull()])/len(size_reported)*100, "% of the size values are numerical.")
# Out:
# 8.026983828506957 % of the size values are numerical.

# %%
def has_numbers(size_string):
    return any(char.isdigit() for char in size_string)

# %%
size_reported['has_numbers'] = size_reported['size'].apply(has_numbers)

# %%
print(len(size_reported[size_reported['has_numbers'] == True])/len(size_reported)*100, "% of the size values are numerical.")
# Out:
# 64.0807164347499 % of the size values are numerical.

# %% [markdown]
# # Now, we explore all the protests with size variables

# %%
numerical_size_reported = size_reported[~size_reported['numerical_size'].isnull()].reset_index(drop=True)
numerical_size_reported
# Out:
#        data_id  iso event_id_cnty  event_id_no_cnty  event_date  year  \
# 0      9634744  484      MEX67204             67204  2022-11-11  2022
# 1      9634783  484      MEX67177             67177  2022-11-11  2022
# 2      9638563  578       NOR1055              1055  2022-11-11  2022
# 3      9640439  380      ITA17704             17704  2022-11-11  2022
# 4      9640478  380      ITA17705             17705  2022-11-11  2022
# ...        ...  ...           ...               ...         ...   ...
# 13655  8789485  104       MMR7256              7256  2010-05-01  2010
# 13656  8789487  104       MMR7248              7248  2010-03-08  2010
# 13657  5955375  104       MMR7240              7240  2010-02-19  2010
# 13658  8789282  104       MMR7238              7238  2010-02-17  2010
# 13659  7988427  764       THA7559              7559  2010-01-29  2010
#
#        time_precision event_type             sub_event_type  \
# 0                   1   Protests           Peaceful protest
# 1                   1   Protests           Peaceful protest
# 2                   1   Protests  Protest with intervention
# 3                   1   Protests  Protest with intervention
# 4                   1   Protests  Protest with intervention
# ...               ...        ...                        ...
# 13655               1   Protests           Peaceful protest
# 13656               1   Protests           Peaceful protest
# 13657               1   Protests           Peaceful protest
# 13658               1   Protests           Peaceful protest
# 13659               1   Protests           Peaceful protest
#
#                       actor1  ... geo_precision             source  \
# 0        Protesters (Mexico)  ...             1      La Silla Rota
# 1        Protesters (Mexico)  ...             1            Milenio
# 2       Protesters (Denmark)  ...             1  Oslo Politiet; VG
# 3         Protesters (Italy)  ...             1    Secolo D'Italia
# 4         Protesters (Italy)  ...             1       Torino Today
# ...                      ...  ...           ...                ...
# 13655   Protesters (Myanmar)  ...             2    Radio Free Asia
# 13656   Protesters (Myanmar)  ...             2    Radio Free Asia
# 13657   Protesters (Myanmar)  ...             1    Radio Free Asia
# 13658   Protesters (Myanmar)  ...             2    Radio Free Asia
# 13659  Protesters (Thailand)  ...             1          Prachatai
#
#              source_scale                                              notes  \
# 0                National  On 11 November 2022, in Ciudad de Mexico - Tla...
# 1                National  On 11 November 2022, in Ciudad de Mexico - Ben...
# 2      New media-National  On 11 November 2022, three environmental activ...
# 3                National  On 11 November 2022, five Last Generation acti...
# 4             Subnational  On 11 November 2022, for the second consecutiv...
# ...                   ...                                                ...
# 13655            Regional  On 1 May 2010, in Sanchaung Township, in Yango...
# 13656            Regional  On 8 March 2010, in Hlaingthayar Township, in ...
# 13657            Regional  On 19 February 2010, in Shwepyithar Township, ...
# 13658            Regional  On 17 February 2010, in Insein Township, in Ya...
# 13659            National  On 29 January 2010, four hundred members of th...
#
#        fatalities   timestamp iso3 size numerical_size has_numbers
# 0               0  1668453946  MEX   40           40.0        True
# 1               0  1668453946  MEX   20           20.0        True
# 2               0  1668530072  NOR    3            3.0        True
# 3               0  1668531724  ITA    5            5.0        True
# 4               0  1668531724  ITA   46           46.0        True
# ...           ...         ...  ...  ...            ...         ...
# 13655           0  1642517539  MMR   30           30.0        True
# 13656           0  1642517539  MMR  500          500.0        True
# 13657           0  1618564884  MMR  400          400.0        True
# 13658           0  1642517538  MMR   80           80.0        True
# 13659           0  1620775298  THA  400          400.0        True
#
# [13660 rows x 34 columns]

# %%
protests[protests.duplicated(['event_id_cnty'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [data_id, iso, event_id_cnty, event_id_no_cnty, event_date, year, time_precision, event_type, sub_event_type, actor1, assoc_actor_1, inter1, actor2, assoc_actor_2, inter2, interaction, region, country, admin1, admin2, admin3, location, latitude, longitude, geo_precision, source, source_scale, notes, fatalities, timestamp, iso3, size]
# Index: []
#
# [0 rows x 32 columns]

# %%
sameday_events = protests[protests.duplicated(subset=['event_date', 'iso'], keep=False)]
sameday_events.iloc[0]
# Out:
# data_id                                                       9633791
# iso                                                               710
# event_id_cnty                                                SAF17883
# event_id_no_cnty                                                17883
# event_date                                                 2022-11-11
# year                                                             2022
# time_precision                                                      1
# event_type                                                   Protests
# sub_event_type                                       Peaceful protest
# actor1                                      Protesters (South Africa)
# assoc_actor_1       SAMWU: South African Municipal Workers Union; ...
# inter1                                                              6
# actor2                                                            NaN
# assoc_actor_2                                                     NaN
# inter2                                                              0
# interaction                                                        60
# region                                                Southern Africa
# country                                                  South Africa
# admin1                                                        Gauteng
# admin2                                           City of Johannesburg
# admin3                                           City of Johannesburg
# location                                  Johannesburg - Braamfontein
# latitude                                                     -26.1982
# longitude                                                     28.0219
# geo_precision                                                       1
# source              GardaWorld; SABC News; News24 (South Africa); EWN
# source_scale                                           Other-National
# notes               On 11 November 2022, about 200 SAMWU-led munic...
# fatalities                                                          0
# timestamp                                                  1668446884
# iso3                                                              ZAF
# size                                                        about 200
# Name: 0, dtype: object

# %%
ZAF = sameday_events[sameday_events['iso']==710]
ZAF[ZAF['year']==2022]
# Out:
#         data_id  iso event_id_cnty  event_id_no_cnty  event_date  year  \
# 0       9633791  710      SAF17883             17883  2022-11-11  2022
# 1       9633792  710      SAF17884             17884  2022-11-11  2022
# 3       9633988  710      SAF17871             17871  2022-11-11  2022
# 5       9634020  710      SAF17885             17885  2022-11-11  2022
# 237     9633787  710      SAF17873             17873  2022-11-10  2022
# ...         ...  ...           ...               ...         ...   ...
# 119997  8786806  710      SAF16038             16038  2022-01-10  2022
# 121257  8706247  710      SAF16027             16027  2022-01-07  2022
# 121366  8786615  710      SAF16033             16033  2022-01-07  2022
# 122261  8705903  710      SAF16023             16023  2022-01-04  2022
# 122263  8706245  710      SAF16024             16024  2022-01-04  2022
#
#         time_precision event_type    sub_event_type  \
# 0                    1   Protests  Peaceful protest
# 1                    1   Protests  Peaceful protest
# 3                    1   Protests  Peaceful protest
# 5                    1   Protests  Peaceful protest
# 237                  1   Protests  Peaceful protest
# ...                ...        ...               ...
# 119997               1   Protests  Peaceful protest
# 121257               1   Protests  Peaceful protest
# 121366               1   Protests  Peaceful protest
# 122261               1   Protests  Peaceful protest
# 122263               1   Protests  Peaceful protest
#
#                            actor1  ... latitude  longitude geo_precision  \
# 0       Protesters (South Africa)  ... -26.1982    28.0219             1
# 1       Protesters (South Africa)  ... -29.8579    31.0292             1
# 3       Protesters (South Africa)  ... -33.9253    18.4239             1
# 5       Protesters (South Africa)  ... -33.9253    18.4239             1
# 237     Protesters (South Africa)  ... -25.7449    28.1878             1
# ...                           ...  ...      ...        ...           ...
# 119997  Protesters (South Africa)  ... -25.6561    28.0928             1
# 121257  Protesters (South Africa)  ... -32.9032    18.7570             1
# 121366  Protesters (South Africa)  ... -28.7333    24.7667             1
# 122261  Protesters (South Africa)  ... -33.9180    25.5701             1
# 122263  Protesters (South Africa)  ... -32.9032    18.7570             1
#
#                                                    source    source_scale  \
# 0       GardaWorld; SABC News; News24 (South Africa); EWN  Other-National
# 1                          Times (South Africa); GroundUp        National
# 3                                                GroundUp        National
# 5                                   News24 (South Africa)        National
# 237                            News24 (South Africa); EWN        National
# ...                                                   ...             ...
# 119997                                          SABC News        National
# 121257                              News24 (South Africa)        National
# 121366                          Diamond Fields Advertiser        National
# 122261                              Herald (South Africa)     Subnational
# 122263                              News24 (South Africa)        National
#
#                                                     notes fatalities  \
# 0       On 11 November 2022, about 200 SAMWU-led munic...          0
# 1       On 11 November 2022, more than 200 protesters ...          0
# 3       On 11 November 2022, about 300 NUPSAW-led comm...          0
# 5       On 11 November 2022, more than 100 protesters,...          0
# 237     On 10 November 2022, for the second day, hundr...          0
# ...                                                   ...        ...
# 119997  On 10 January 2022, parents gathered at Akasia...          0
# 121257  On 7 January 2022, a group gathered at the Pik...          0
# 121366  On 7 January 2022, a group gathered in front o...          0
# 122261  On 4 January 2022, about 150 members of the Ra...          0
# 122263  On 4 January 2022, a group gathered at the Pik...          0
#
#          timestamp iso3           size
# 0       1668446884  ZAF      about 200
# 1       1668446884  ZAF  more than 200
# 3       1668446884  ZAF      about 300
# 5       1668446884  ZAF  more than 100
# 237     1668446884  ZAF       hundreds
# ...            ...  ...            ...
# 119997  1642443563  ZAF      no report
# 121257  1641863887  ZAF      no report
# 121366  1642443562  ZAF      no report
# 122261  1641863886  ZAF      about 150
# 122263  1641863887  ZAF      no report
#
# [1090 rows x 32 columns]

# %%
n_by_cnty = protests.groupby("iso3")["event_id_cnty"].count()
n_by_cnty
# Out:
# iso3
# ABW      15
# AFG     999
# AGO     419
# AIA       3
# ALB     934
#        ...
# XKX     524
# YEM    2889
# ZAF    9201
# ZMB     345
# ZWE     971
# Name: event_id_cnty, Length: 220, dtype: int64

# %%
# 220 countries in total
cnty = list(protests['iso3'].unique())

# %%
protests[protests['iso3'] == 'ZAF']
# Out:
#         data_id  iso event_id_cnty  event_id_no_cnty  event_date  year  \
# 0       9633791  710      SAF17883             17883  2022-11-11  2022
# 1       9633792  710      SAF17884             17884  2022-11-11  2022
# 3       9633988  710      SAF17871             17871  2022-11-11  2022
# 5       9634020  710      SAF17885             17885  2022-11-11  2022
# 237     9633787  710      SAF17873             17873  2022-11-10  2022
# ...         ...  ...           ...               ...         ...   ...
# 678246  7526069  710         SAF13                13  1997-03-13  1997
# 678254  6875985  710          SAF7                 7  1997-02-07  1997
# 678255  6875992  710          SAF5                 5  1997-02-06  1997
# 678256  7526041  710          SAF6                 6  1997-02-06  1997
# 678275  8555371  710          SAF2                 2  1997-01-09  1997
#
#         time_precision event_type                      sub_event_type  \
# 0                    1   Protests                    Peaceful protest
# 1                    1   Protests                    Peaceful protest
# 3                    1   Protests                    Peaceful protest
# 5                    1   Protests                    Peaceful protest
# 237                  1   Protests                    Peaceful protest
# ...                ...        ...                                 ...
# 678246               1   Protests                    Peaceful protest
# 678254               1   Protests                    Peaceful protest
# 678255               1   Protests                    Peaceful protest
# 678256               1   Protests  Excessive force against protesters
# 678275               1   Protests                    Peaceful protest
#
#                            actor1  ... latitude  longitude geo_precision  \
# 0       Protesters (South Africa)  ... -26.1982    28.0219             1
# 1       Protesters (South Africa)  ... -29.8579    31.0292             1
# 3       Protesters (South Africa)  ... -33.9253    18.4239             1
# 5       Protesters (South Africa)  ... -33.9253    18.4239             1
# 237     Protesters (South Africa)  ... -25.7449    28.1878             1
# ...                           ...  ...      ...        ...           ...
# 678246  Protesters (South Africa)  ... -26.2667    27.8667             1
# 678254  Protesters (South Africa)  ... -33.9253    18.4239             1
# 678255  Protesters (South Africa)  ... -25.7449    28.1878             1
# 678256  Protesters (South Africa)  ... -26.2667    27.8667             1
# 678275  Protesters (South Africa)  ... -25.6667    27.2500             1
#
#                                                    source    source_scale  \
# 0       GardaWorld; SABC News; News24 (South Africa); EWN  Other-National
# 1                          Times (South Africa); GroundUp        National
# 3                                                GroundUp        National
# 5                                   News24 (South Africa)        National
# 237                            News24 (South Africa); EWN        National
# ...                                                   ...             ...
# 678246                                            Reuters   International
# 678254                                            Reuters   International
# 678255                                       Local Source     Subnational
# 678256                                            Reuters   International
# 678275                                            Reuters   International
#
#                                                     notes fatalities  \
# 0       On 11 November 2022, about 200 SAMWU-led munic...          0
# 1       On 11 November 2022, more than 200 protesters ...          0
# 3       On 11 November 2022, about 300 NUPSAW-led comm...          0
# 5       On 11 November 2022, more than 100 protesters,...          0
# 237     On 10 November 2022, for the second day, hundr...          0
# ...                                                   ...        ...
# 678246  Zulu nationals protest to commemorate the deat...          0
# 678254  Demonstrators gather during a speech by Presid...          0
# 678255  COSATU members protest outside the Swaziland H...          0
# 678256  A group of demonstrators blocked roadways in p...          4
# 678275  The NUM, the mining union which the Rustenburg...          0
#
#          timestamp iso3           size
# 0       1668446884  ZAF      about 200
# 1       1668446884  ZAF  more than 200
# 3       1668446884  ZAF      about 300
# 5       1668446884  ZAF  more than 100
# 237     1668446884  ZAF       hundreds
# ...            ...  ...            ...
# 678246  1611019330  ZAF           None
# 678254  1582579225  ZAF           None
# 678255  1582579225  ZAF           None
# 678256  1611019330  ZAF           None
# 678275  1632239615  ZAF           None
#
# [9201 rows x 32 columns]

# %%
def create_df(df, colname, category):
    return df[df[colname] == category]

# %%
for category in cnty:
    create_df(protests, 'iso3', category)
